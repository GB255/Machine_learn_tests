# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN

# %%
df = pd.read_csv('agrupamento.csv', sep=';')
df.index = np.arange(1,len(df)+1)
base = np.array(df)

df
# Out:
#    1   2   3   4   5
# 1  0   2   8   9   7
# 2  2   0   7   8  11
# 3  8   7   0  11   6
# 4  9   8  11   0   5
# 5  7  11   6   5   0

# %%
scaler = StandardScaler()
base = scaler.fit_transform(base)

dendrograma = dendrogram(linkage(base, method = 'ward'))
plt.title('Dendrograma')
plt.xlabel('Pessoas')
plt.ylabel('Distância Euclidiana')

hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')

# %%
base
# Out:
# array([[-1.46726488, -0.893325  ,  0.44307902,  0.62725005,  0.33859959],
#        [-0.90293224, -1.38961667,  0.16615463,  0.36589586,  1.46726488],
#        [ 0.79006571,  0.34740417, -1.77231608,  1.14995842,  0.05643326],
#        [ 1.07223203,  0.59555   ,  1.27385218, -1.72493763, -0.22573306],
#        [ 0.50789938,  1.3399875 , -0.11076976, -0.4181667 , -1.63656468]])

# %%
clustering = DBSCAN(eps=6, min_samples=3).fit(base)

# %%
clustering.labels_
# Out:
# array([0, 0, 0, 0, 0], dtype=int64)
